# %% [markdown]
# import numpy as np
# import cv2
# img=cv2.imread("C:\\Users\\Acer\\Downloads\\2. Practice\\Task 1A\\task_1a_images\\maze01.jpg", 1)
#
# #CONVERTING TO GRAY AND THEN BINARY
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ret, binary = cv2.threshold(gray,10,255,cv2.THRESH_BINARY)
# print(binary.shape)
#
# #choosing a block of the full image named as target
# target=binary[0:20,0:20]
#
# #checking for the upper wall
# if target[0,10]==0:
#     print("top")
#
# #checking for the bottom wall
# if target[19,10]==0:
#     print("bottom")
#
# #checking for the left wall
# if target[10,0]==0:
#     print("left")
#
# #checking for the right wall
# if target[19,10]==0:
#     print("bottom")
#
# cv2.imshow('BINARY',binary[0:20,20:40])
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import numpy as np
import cv2 
img=cv2.imread("C:\\Users\\Acer\\Downloads\\2. Practice\\Task 1A\\task_1a_images\\maze01.jpg")

#CONVERTING TO GRAY AND THEN BINARY 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
ret, binary = cv2.threshold(gray,10,255,cv2.THRESH_BINARY) 
print(binary.shape)



for a in range(0,200,20):
    for b in range(0,200,20):
        #choosing a block of the full image named as target 
        target=binary[a:a+20,b:b+20]
        
        x=0
        y=0
        #checking for the upper wall 
        if target[x,y+10]==0:
            print("top")

        #checking for the bottom wall 
        if target[x+19,y+10]==0:
            print("bottom")

        #checking for the left wall 
        if target[x+10,y]==0:
            print("left")

        #checking for the right wall
        if target[x+10,y+19]==0:
            print("right")
         
        print(b)
    
    print(a)
cv2.imshow('Target',target) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
# Out:
# (200, 200)
# top
# left
# 0
# top
# right
# 20
# top
# bottom
# left
# 40
# top
# 60
# top
# bottom
# right
# 80
# top
# left
# right
# 100
# top
# left
# right
# 120
# top
# left
# right
# 140
# top
# left
# right
# 160
# top
# left
# right
# 180
# 0
# bottom
# left
# right
# 0
# left
# 20
# top
# bottom
# right
# 40
# left
# right
# 60
# top
# left
# right
# 80
# left
# right
# 100
# left
# 120
# 140
# bottom
# right
# 160
# left
# right
# 180
# 20
# top
# left
# right
# 0
# bottom
# left
# 20
# top
# 40
# bottom
# right
# 60
# left
# 80
# bottom
# right
# 100
# bottom
# left
# right
# 120
# bottom
# left
# 140
# top
# 160
# bottom
# right
# 180
# 40
# bottom
# left
# 0
# top
# bottom
# 20
# right
# 40
# top
# left
# 60
# bottom
# right
# 80
# top
# left
# 100
# top
# bottom
# right
# 120
# top
# bottom
# left
# 140
# 160
# top
# bottom
# right
# 180
# 60
# top
# left
# right
# 0
# top
# left
# right
# 20
# bottom
# left
# 40
# 60
# top
# bottom
# right
# 80
# left
# right
# 100
# top
# left
# right
# 120
# top
# bottom
# left
# 140
# 160
# top
# right
# 180
# 80
# left
# 0
# right
# 20
# top
# bottom
# left
# 40
# 60
# top
# bottom
# right
# 80
# left
# right
# 100
# left
# right
# 120
# top
# bottom
# left
# 140
# right
# 160
# bottom
# left
# right
# 180
# 100
# left
# right
# 0
# bottom
# left
# right
# 20
# top
# left
# 40
# bottom
# right
# 60
# top
# left
# 80
# bottom
# right
# 100
# left
# right
# 120
# top
# left
# right
# 140
# left
# 160
# top
# bottom
# right
# 180
# 120
# left
# 0
# top
# right
# 20
# bottom
# left
# 40
# top
# right
# 60
# left
# right
# 80
# top
# left
# 100
# bottom
# right
# 120
# left
# right
# 140
# left
# right
# 160
# top
# left
# right
# 180
# 140
# left
# right
# 0
# bottom
# left
# 20
# top
# 40
# bottom
# 60
# bottom
# 80
# 100
# top
# bottom
# 120
# 140
# 160
# right
# 180
# 160
# bottom
# left
# right
# 0
# top
# bottom
# left
# 20
# bottom
# right
# 40
# top
# bottom
# left
# 60
# top
# bottom
# 80
# bottom
# 100
# top
# bottom
# right
# 120
# bottom
# left
# right
# 140
# bottom
# left
# right
# 160
# bottom
# left
# right
# 180
# 180
